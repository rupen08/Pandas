# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("jamesbond.csv")
a
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
a.describe(include  = "all")
# Out:
#                  Film         Year        Actor   Director  Box Office  \
# count              26    26.000000           26         26   26.000000
# unique             25          NaN            7         13         NaN
# top     Casino Royale          NaN  Roger Moore  John Glen         NaN
# freq                2          NaN            7          5         NaN
# mean              NaN  1983.576923          NaN        NaN  491.611538
# std               NaN    16.295209          NaN        NaN  176.740396
# min               NaN  1962.000000          NaN        NaN  250.900000
# 25%               NaN  1969.500000          NaN        NaN  375.350000
# 50%               NaN  1982.000000          NaN        NaN  461.750000
# 75%               NaN  1996.500000          NaN        NaN  534.500000
# max               NaN  2015.000000          NaN        NaN  943.500000
#
#             Budget  Bond Actor Salary
# count    26.000000          18.000000
# ...

# %%
q = a["Bond Actor Salary"].quantile(0.99)

# %%
a1 = a[a["Bond Actor Salary"] < q]

# %%
a1
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# ...

# %%
a1.describe(include = "all")
# Out:
#                                    Film         Year         Actor   Director  \
# count                                17    17.000000            17         17
# unique                               17          NaN             6         10
# top     On Her Majesty's Secret Service          NaN  Sean Connery  John Glen
# freq                                  1          NaN             6          4
# mean                                NaN  1983.647059           NaN        NaN
# std                                 NaN    17.251598           NaN        NaN
# min                                 NaN  1962.000000           NaN        NaN
# 25%                                 NaN  1967.000000           NaN        NaN
# 50%                                 NaN  1985.000000           NaN        NaN
# 75%                                 NaN  1997.000000           NaN        NaN
# max                                 NaN  2012.000000           NaN        NaN
#
# ...

# %%
q = a1["Box Office"].quantile(0.99)

# %%
a2 = a1[a1["Box Office"]<q]

# %%
a2
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# ...

# %%
data_cleaned = a2.reset_index(drop = True)

# %%
data_cleaned
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 5   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 6              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 7                         Octopussy  1983     Roger Moore           John Glen
# 8                  A View to a Kill  1985     Roger Moore           John Glen
# 9              The Living Daylights  1987  Timothy Dalton           John Glen
# 10                  Licence to Kill  1989  Timothy Dalton           John Glen
# ...

# %%
import pandas as pd
import numpy as np


df1 = pd.DataFrame ({
    "Name" : ["Rupen", "Nikhil", "Hetal"],
    "Age" : [20, 14, 14]
})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df1["Age"].mode()
# Out:
# 0    14
# dtype: int64

# %%
a.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
(a[(a["Actor"] != "Sean Connery") & (a["Actor"] != "Roger Moore")])
# Out:
#                                Film  Year           Actor            Director  \
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# ...

# %%
columns = a.columns.tolist()

# %%
columns = [c for c in columns if c not in ["Year"]]

# %%
columns
# Out:
# ['Film', 'Actor', 'Director', 'Box Office', 'Budget', 'Bond Actor Salary']
