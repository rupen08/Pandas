# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ["MSFT", "GOOG", "AAPL" , "AMZN", "TSLA"]

# %%
p = data.DataReader(name = companies, data_source = "yahoo", start = "2010-01-01", end = "2021-03-24")

# %%
p
# Out:
# Attributes   Adj Close                                                    \
# Symbols           MSFT         GOOG        AAPL         AMZN        TSLA
# Date
# 2010-01-04   24.049969   312.204773    6.583586   133.899994         NaN
# 2010-01-05   24.057743   310.829926    6.594968   134.690002         NaN
# 2010-01-06   23.910097   302.994293    6.490066   132.250000         NaN
# 2010-01-07   23.661432   295.940735    6.478067   130.000000         NaN
# 2010-01-08   23.824627   299.885956    6.521136   133.520004         NaN
# ...                ...          ...         ...          ...         ...
# 2021-03-18  230.720001  2036.219971  120.529999  3027.989990  653.159973
# 2021-03-19  230.350006  2043.199951  119.989998  3074.959961  654.869995
# 2021-03-22  235.990005  2038.589966  123.389999  3110.870117  670.000000
# 2021-03-23  237.580002  2052.959961  122.540001  3137.500000  662.159973
# 2021-03-24  235.460007  2045.060059  120.089996  3087.070068  630.270020
#
# ...

# %%
p.shape
# Out:
# (2825, 30)

# %%
p.ndim
# Out:
# 2

# %%
(p["Close"])
# Out:
# Symbols           MSFT         GOOG        AAPL         AMZN        TSLA
# Date
# 2010-01-04   30.950001   312.204773    7.643214   133.899994         NaN
# 2010-01-05   30.959999   310.829926    7.656429   134.690002         NaN
# 2010-01-06   30.770000   302.994293    7.534643   132.250000         NaN
# 2010-01-07   30.450001   295.940735    7.520714   130.000000         NaN
# 2010-01-08   30.660000   299.885956    7.570714   133.520004         NaN
# ...                ...          ...         ...          ...         ...
# 2021-03-18  230.720001  2036.219971  120.529999  3027.989990  653.159973
# 2021-03-19  230.350006  2043.199951  119.989998  3074.959961  654.869995
# 2021-03-22  235.990005  2038.589966  123.389999  3110.870117  670.000000
# 2021-03-23  237.580002  2052.959961  122.540001  3137.500000  662.159973
# 2021-03-24  235.460007  2045.060059  120.089996  3087.070068  630.270020
#
# [2825 rows x 5 columns]

# %%
p.axes
# Out:
# [DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                 '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                 '2010-01-14', '2010-01-15',
#                 ...
#                 '2021-03-11', '2021-03-12', '2021-03-15', '2021-03-16',
#                 '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-22',
#                 '2021-03-23', '2021-03-24'],
#                dtype='datetime64[ns]', name='Date', length=2825, freq=None),
#  MultiIndex([('Adj Close', 'MSFT'),
#              ('Adj Close', 'GOOG'),
#              ('Adj Close', 'AAPL'),
#              ('Adj Close', 'AMZN'),
#              ('Adj Close', 'TSLA'),
#              (    'Close', 'MSFT'),
#              (    'Close', 'GOOG'),
#              (    'Close', 'AAPL'),
#              (    'Close', 'AMZN'),
#              (    'Close', 'TSLA'),
#              (     'High', 'MSFT'),
#              (     'High', 'GOOG'),
#              (     'High', 'AAPL'),
# ...

# %%
p["Close"]["AAPL"]
# Out:
# Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2021-03-18    120.529999
# 2021-03-19    119.989998
# 2021-03-22    123.389999
# 2021-03-23    122.540001
# 2021-03-24    120.089996
# Name: AAPL, Length: 2825, dtype: float64
